# %% [markdown]
# 8th Sept Assignment
#
# 1. take car crashes dataset (seaborn inbuilt library)
# 2. Load the dataset
# 3. Perform all data visualization steps
# 4. Inference is must for each and every graph
# 5. submit by wednesday in html or pdf format

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load car-crashes dataset
df=sns.load_dataset("car_crashes")

# %%
df
# Out:
#     total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0    18.8     7.332    5.640          18.048       15.040       784.55
# 1    18.1     7.421    4.525          16.290       17.014      1053.48
# 2    18.6     6.510    5.208          15.624       17.856       899.47
# 3    22.4     4.032    5.824          21.056       21.280       827.34
# 4    12.0     4.200    3.360          10.920       10.680       878.41
# 5    13.6     5.032    3.808          10.744       12.920       835.50
# 6    10.8     4.968    3.888           9.396        8.856      1068.73
# 7    16.2     6.156    4.860          14.094       16.038      1137.87
# 8     5.9     2.006    1.593           5.900        5.900      1273.89
# 9    17.9     3.759    5.191          16.468       16.826      1160.13
# 10   15.6     2.964    3.900          14.820       14.508       913.15
# 11   17.5     9.450    7.175          14.350       15.225       861.18
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   total           51 non-null     float64
#  1   speeding        51 non-null     float64
#  2   alcohol         51 non-null     float64
#  3   not_distracted  51 non-null     float64
#  4   no_previous     51 non-null     float64
#  5   ins_premium     51 non-null     float64
#  6   ins_losses      51 non-null     float64
#  7   abbrev          51 non-null     object
# dtypes: float64(7), object(1)
# memory usage: 3.3+ KB

# %%
df.head(5)
# Out:
#    total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0   18.8     7.332    5.640          18.048       15.040       784.55
# 1   18.1     7.421    4.525          16.290       17.014      1053.48
# 2   18.6     6.510    5.208          15.624       17.856       899.47
# 3   22.4     4.032    5.824          21.056       21.280       827.34
# 4   12.0     4.200    3.360          10.920       10.680       878.41
#
#    ins_losses abbrev
# 0      145.08     AL
# 1      133.93     AK
# 2      110.35     AZ
# 3      142.39     AR
# 4      165.63     CA

# %%
df.tail(5)
# Out:
#     total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 46   12.7     2.413    3.429          11.049       11.176       768.95
# 47   10.6     4.452    3.498           8.692        9.116       890.03
# 48   23.8     8.092    6.664          23.086       20.706       992.61
# 49   13.8     4.968    4.554           5.382       11.592       670.31
# 50   17.4     7.308    5.568          14.094       15.660       791.14
#
#     ins_losses abbrev
# 46      153.72     VA
# 47      111.62     WA
# 48      152.56     WV
# 49      106.62     WI
# 50      122.04     WY

# %%
sns.scatterplot(x="total",y="alcohol",data=df)
# Out:
# <Axes: xlabel='total', ylabel='alcohol'>

# %% [markdown]
# INFERENCE: As the total crashes increased, the no. crashes due to alcohol also increased

# %%
sns.scatterplot(x="not_distracted",y="speeding",data=df)
# Out:
# <Axes: xlabel='not_distracted', ylabel='speeding'>

# %% [markdown]
# INFERENCE: Not distracted people tend to crash due to speeding more

# %%
sns.lineplot(x="total",y="alcohol",data=df)
# Out:
# <Axes: xlabel='total', ylabel='alcohol'>

# %% [markdown]
# INFERENCE: The graph fluctuates in the middle but on an average the value of crashes due to alcohol increases with the total no. of crashes

# %%
sns.lineplot(x="total",y="not_distracted",data=df)
# Out:
# <Axes: xlabel='total', ylabel='not_distracted'>

# %% [markdown]
# INFERENCE: value of not distracted people increases with total value except for the sudden drops at x=14 and x=17.5

# %%
sns.distplot(df["alcohol"])
# Out:
# <ipython-input-17-281d56044cde>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["alcohol"])
# <Axes: xlabel='alcohol', ylabel='Density'>

# %% [markdown]
# INFERENCE: Alcohol crashes value ranges mostly between 4 to 6.

# %%
sns.relplot(x="total",y="alcohol",data=df,hue="abbrev")

# %%
df["alcohol"].value_counts()
# Out:
# 5.208     2
# 5.640     1
# 4.218     1
# 4.704     1
# 3.480     1
# 3.136     1
# 4.968     1
# 3.567     1
# 10.038    1
# 4.794     1
# 5.771     1
# 3.328     1
# 5.642     1
# 9.799     1
# 9.416     1
# 6.402     1
# 5.655     1
# 7.372     1
# 1.808     1
# 4.080     1
# 3.429     1
# 3.498     1
# 6.664     1
# 4.554     1
# 5.215     1
# 5.474     1
# 4.525     1
# 5.456     1
# 5.824     1
# 3.360     1
# 3.808     1
# 3.888     1
# 4.860     1
# 1.593     1
# 5.191     1
# 3.900     1
# 7.175     1
# 4.437     1
# 4.352     1
# 4.205     1
# 3.925     1
# 4.272     1
# 4.922     1
# 6.765     1
# 4.530     1
# 4.000     1
# 2.870     1
# 3.948     1
# 2.784     1
# 5.568     1
# Name: alcohol, dtype: int64

# %%
sns.barplot(data=df,x="total",y="alcohol")
# Out:
# <Axes: xlabel='total', ylabel='alcohol'>

# %%
sns.countplot(x="total",data=df)
# Out:
# <Axes: xlabel='total', ylabel='count'>

# %%
sns.jointplot(x="total",y="alcohol",data=df)

# %%
sns.boxplot(x="total",y="alcohol",data=df)
# Out:
# <Axes: xlabel='total', ylabel='alcohol'>

# %%
cor=df.corr()
cor
# Out:
# <ipython-input-30-7a446f931109>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   cor=df.corr()
#                    total  speeding   alcohol  not_distracted  no_previous  \
# total           1.000000  0.611548  0.852613        0.827560     0.956179
# speeding        0.611548  1.000000  0.669719        0.588010     0.571976
# alcohol         0.852613  0.669719  1.000000        0.732816     0.783520
# not_distracted  0.827560  0.588010  0.732816        1.000000     0.747307
# no_previous     0.956179  0.571976  0.783520        0.747307     1.000000
# ins_premium    -0.199702 -0.077675 -0.170612       -0.174856    -0.156895
# ins_losses     -0.036011 -0.065928 -0.112547       -0.075970    -0.006359
#
#                 ins_premium  ins_losses
# total             -0.199702   -0.036011
# ...

# %%
sns.heatmap(cor,annot=True)
# Out:
# <Axes: >
